# %%
import pyperclip
import re
import urllib
import requests
from bs4 import BeautifulSoup
import selenium

import warnings
warnings.filterwarnings("ignore")

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

# %%
url = "http://api.aoikujira.com/time/get.php"
r = requests.get(url).text
print(r)
b = requests.get(url).content
print(b)
# Out:
# 2023/05/04 09:21:21
# b'2023/05/04 09:21:21'

# %%
# url = "http://naver.com"를 텍스트와 바이너리로 가져오세요.
url = "http://naver.com"
r = requests.get(url).text
print(r)
b = requests.get(url).content
print(b)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
# requests로 요청 시 데이터를 실어 보내는 경우 데이터를 딕셔너리 형태로 만들어 보내는 방식(get 방식)
# url = "http://naver.com"을 "https://www.naver.com/?key1=value1&key2=value2"로 만드세요.

url = "http://naver.com"
res = requests.get(url, params = {"key1":"value1", "key2":"value2"})
print(res.url)
# Out:
# https://www.naver.com/?key1=value1&key2=value2

# %%
# post 요청 시 데이터가 url에 포함되지 않고 header의 body에 포함됨
# body 데이터 추가 시 data를 사용

url = "http://naver.com"
res = requests.post(url, data = {"key1":"value1", "key2":"value2"})
print(res.url)
# Out:
# https://www.naver.com/

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100"
req = requests.get(url, headers=headers)
bs = BeautifulSoup(req.content, 'html.parser')
print(bs.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta contents="always" name="referrer"/>
#   <meta content="600" http-equiv="refresh">
#    <meta content="width=1106" name="viewport">
#     <meta content="정치 : 네이버 뉴스" property="og:title"/>
#     <meta content="website" property="og:type"/>
#     <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
#     <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
#      <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
#      <meta content="네이버" property="og:article:author">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
#       <meta content="네이버 뉴스" name="twitter:site"/>
#       <meta content="네이버 뉴스" name="twitter:creator"/>
# ...

# %%
# 기본 태그를 사용해서 해당하는 첫번째 텍스트와 전체 텍스트를 출력
#1
bs.find('a').text

te = bs.find_all('a')
for i in te:
    print(i.text)

#2
bs.find('span', class_='tx').text

te = bs.findAll('span', class_='tx')
for i in te:
    print(i.text)

#3
bs.find('div')

te = bs.findAll('div')
for i in te:
    print(i.text)

#4
te = bs.find_all('span', {'class':'blind','class':"tx"})
for i in te:
    print(i.text)
    
# 5.
bs.select_one('div#u_skip a span').text

# 6.
te = bs.select('div#u_skip a span')
for i in te:
    print(i.text)
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 전현희, 감사원 앞 1인 시위…"감사원 조작감사, 사죄하라"
# 전현희, 감사원 전원위서 4시간 넘게 소명…최재해 원장도 참석(종합)
# 전현희, 감사원 앞 1인 시위 "조작감사 사죄하고 징계 철회하라"
# '근태' 감사받는 전현희, 감사원 직접 나와 "불법 조작 감사"(종합)
# 30개의 관련뉴스 더보기
#
#
#
# 尹 "ADB가 경인고속道 지원했듯 … 韓도 적극 기여"
# 韓·ADB, 서울에 기후 네트워크 거점 설립
# 윤 대통령 "인도 · 태평양 개발에 적극 기여…협력적 공급망 구축"
# [속보]尹 “韓·ADB 공동으로 기후기술허브 설치…민관 함께 문제 해결하는 플랫폼”
# 80개의 관련뉴스 더보기
#
#
#
# 전세사기 피해자들 울부짖는데… '지원 특별법' 난항
# 전세피해 지원 '진통'…대상·방식 합의 못해
# 국회 국토교통위, 오늘 전세 사기 피해지원 특별법 심사 재개
# 여야 ‘전세사기 특별법’ 합의 이틀째 불발…금주 내 처리 사실상 무산
# 62개의 관련뉴스 더보기
#
#
#
# 日, 민주 전용기 의원 독도 방문에 강력 항의…유감표명·재발방지 요구
# 한일정상회담 앞두고 독도 찾은 의원…일본 항의엔 일축
# 민주당 전용기 의원, 독도 방문…"일 정부, 유감 표명"
# 외교부, 日 '전용기 의원 독도 방문' 항의에 "부당한 주장 일축"
# 94개의 관련뉴스 더보기
#
#
#
# 민주당 '공천 룰' 두고 정치 신인·개딸이 동시에 발끈한 이유는
#
#
#
# ...

# %%
# div 태그를 모두 가져와서 문자와 숫자만 스페이스로 연결해서 출력하세요
import re
for i in bs.find_all('div'):
    print(' '.join(re.findall('[\w]+', i.text)))
# Out:
# 메인 메뉴로 바로가기 본문으로 바로가기 검색 NAVER 뉴스 TV연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 IT 과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 전체 언론사 뉴스스탠드 라이브러리 05 04 목 전체 언론사 뉴스스탠드 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 안내헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출됩니다 닫기 전현희 감사원 앞 1인 시위 감사원 조작감사 사죄하라 기사내용 요약 감사원 대심 출석 한 시간 전 도착해 1인 시위 최재해 유병호는 표적감사 감사위원 제척해야 서울 뉴전현희 국민권익위원장은 3일 감사원 뉴시스 뉴스1 전현희 감사원 전원위서 4시간 넘게 소명 최재해 원장도 참석 종합 중앙일보 전현희 감사원 앞 1인 시위 조작감사 사죄하고 징계 철회하라 연합뉴스 근태 감사받는 전현희 감사원 직접 나와 불법 조작 감사 종합 30개의 관련뉴스 더보기 尹 ADB가 경인고속道 지원했듯 韓도 적극 기여 송도서 ADB 연차총회 개막식 기후기술 허브 서울 공동설치 추경호 지식협력 1억弗 출연 윤석열 대통령이 3일 아시아개발은행 ADB 연차총회에 참석해 매일경제 아시아경제 韓 ADB 서울에 기후 네트워크 거점 설립 SBS 윤 대통령 인도 태평양 개발에 적극 기여 협력적 공급망 구축 서울경제 속보 尹 韓 ADB 공동으로 기후기술허브 설치 민관 함께 문제 해결하는 플랫폼 80개의 관련뉴스 더보기 전세사기 피해자들 울부짖는데 지원 특별법 난항 여야가 3일 전세사기 피해자 지원을 위한 전세사기 피해지원 특별법 제정안을 놓고 머리를 맞댔지만 끝내 합의점을 찾지 못했다 피해자 요건과 임대보증 부산일보 매일경제 전세피해 지원 진통 대상 방식 합의 못해 JTBC 국회 국토교통위 오늘 전세 사기 피해지원 특별법 심사 재개 조선비즈 여야 전세사기 특별법 합의 이틀째 불발 금주 내 처리 사실상 무산 62개의 관련뉴스 더보기 日 민주 전용기 의원 독도 방문에 강력 항의 
# ...

# %% [markdown]
# ### 과제2_0503,
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 id가 'footer'인 한글만 출력하세요

# %% [markdown]
# ### 과제3_0503.
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 p태그가 있는 데이터를 5개만 출력하세요

# %% [markdown]
# ### 과제4_0503.
# url = 'https://news.daum.net/politics' 사이트에서 '정치'를 출력하세요.

# %%
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 
# id가 있는 데이터를 모두 출력하세요
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

r = requests.get(url,headers=headers)
html = r.text
bs = BeautifulSoup(html,'html.parser')
print(bs.find_all(id=True))
# Out:
# [<div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# ...

# %%
bs.select_one('div#u_skip>a>span').text
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.find('div', id='header').find('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
# https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 
# class_='cluster_text'에 있는 모든 한글 text 10개를 출력하세요.

for i in bs.find_all(class_='cluster_text')[:10]:
    print(' '.join(re.findall('[^\n]+',i.text)))
# Out:
# 서울법대 尹 동문 방통위원으로… 野 추천엔 45일째 무응답 윤석열 대통령이 지난달 퇴임한 김창룡 전 방송통신위원회 상임위원 후임으로 이상인 법무법인 오늘 대표변호사를 3일 지명했다. 앞서 더불어민주당이 상임위원으 … 미디어오늘
# 국민일보 尹, 방통위 상임위원에 이상인 변호사 임명…‘BBK특검’서 한솥밥
# 세계일보 尹대통령, 방통위 상임위원에 이상인 변호사 지명
# 디지털타임스 [속보]尹대통령, 신임 방송통위원에 이상인 변호사 지명
# ‘태영호 공천 녹취록’ 일파만파… 비윤계 “내용 사실이면 중대범죄”[뉴스1 PICK] 이진복 대통령실 정무수석이 22대 총선 공천 문제를 거론하며 한일 관계에 대한 옹호 발언을 해달라고 요청했다는 태영호 국민의힘 최고위원의 녹취가 공개되면 … 뉴스1
# MBN 진중권 "태영호 녹취록…박근혜 전 대통령은 이걸로 징역 살아"
# 헤럴드경제 태영호, ‘녹취록 파문’ 추가 징계는 피했다…‘자진사퇴’ 책임론 커져 [이런정치]
# 서울신문 태영호 공천 녹취록 논란… 이진복 “사실무근”
# "땅끝에 주저앉은 감사원" 전현희 직접 감사원 출석해 피켓시위까지 감사원 감사를 받는 전현희 국민권익위원장이 본인 입장을 직접 설명하기 위해 감사 시작 9개월 만에 처음으로 감사원에 출석했습니다. 이번에도 피켓 시위를  … MBN
# 한겨레 “중대한 위법 없음”…공영방송 ‘정치 감사’의 예견된 결말

# %% [markdown]
# ### 과제5_0503.
# 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100%27%EC%97%90%EC%84%9C 뉴스 제목 10개를 가져오세요 (사이트의 뉴스와 일치)

# %% [markdown]
# ### 과제6_0503.
# 상기에서 출력된 데이터를 news.txt 파일로 저장하세요

# %% [markdown]
# ### 과제7_0503.
# 네이버 등 자주 사용하는 웹페이지에서 가치있다고 생각할 수 있는 데이터를 가져와서 활용할 수 있는 형태로 출력하세요.(최소 1000개 이상)
