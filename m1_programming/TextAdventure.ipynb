# %%
DesIndex = [
    "애주가 : 철갑+2Lv, 방어력 +2",
    "염동력자 : 역장+3Lv, 방어력 +2",
    "화염술사 : 최대 체력 +10, 매 턴마다 발화를 2 부여",
    "마법사 체질 : 충전+3Lv, 공격력 +2",
    "용병 출신 : 필살+3Lv, 최대 체력 +30",
    "신세대 독술사 : 전투 시작 시 적에게 중독을 10 부여합니다.",
    "타고난 싸움꾼 : 괴력 +3Lv, 최대 체력 +25",
    "불을 품은 자 : 발화 +3Lv, 최대 체력 +10",
    "철벽의 투사 : 전투 시 3턴마다 피해 감소를 2 얻습니다.",
    "피에 굶주린 자 : 흡혈 +3Lv, 공격력 +1",
    "타고난 야성 : 공격력 +4, 최대 체력 +55, 시작 능력을 제거합니다.",
    "바람의 축복 : 민첩 +2Lv, 신속 +1Lv, 공격력 +1",
    "공포의 대상 : 공격력 +2, 전투 시작 시 적을 마비시킵니다.",
    "암흑가 출신 : 간파 +3Lv, 방어력 +2",
    "특등사수 : 공격력 +3, 적은 첫 6턴 동안 회피할 수 없습니다.",
    "탐색전의 귀재 : 전투 시작 시 무적을 2 얻습니다. 적도 무적이 됩니다.",
    "곰의 영혼 : 매 턴마다 체력이 4 증가됩니다.",
    "축복받은 육체 : 성장 +3Lv, 최대 체력 +25",
    "벼락치기 : 전투 시작 시 가속을 1 얻습니다.",
    "저격수 : 전투 시작 시 우선권을 1 얻습니다."
]


ItemIndex = [
    
]


EnemyIndex1 = [
    "전사한 검사",
    "전사한 습격병",
    "전사한 석궁병",
    "전사한 마도사",
    "전사한 돌격병",
    "전사한 중갑병",
    "잿빛 숲의 괴조"
]

EnemyIndex2 = [
    "문지기",
    "광신도 보병",
    "광신도 사수",
    "광신도 비술사"
]

EnemyIndex3 = [
    "광신도 인도자",
    "광신도 심판자",
    "광신도 수확자",
    "심연의 마녀"
]

EnemyIndex4 = [
    "고대의 선지자",
    "고대의 수호자",
    "고대의 주시자",
    "성화의 주인"
]

EnemyIndex5 = [
    "고대의 살육자",
    "차원 파괴자",
    "고대의 습격자",
    "고대의 전능자"
]

EnemyIndex6 = [
    "고대의 살육자",
    "차원 파괴자",
    "고대의 습격자",
    "불멸의 왕"
]

BossIndex = [
    "굶주린 신목",
    "영원한 전우회",
    "광신의 고룡",
    "멈춰선 패왕",
    "차원 포식자",
    "겨울의 심장"
]

# %%
import random


class Text:
    def sft(self):
        print("="*100)
    def msft(self):
        print("-"*100)
    def pak(self):
        print("\n\n\n>>>press any key")
        print("="*100)
        while True:
            N = input()
            if N == "menu":
                callMenu()
            else:
                break
                
class Encounter:
    
    
    
class Battle:
    def dodge(self):
        r = randint(0,100)
        if r > 6:
            return False
        else:
            return True

    def userDodge(self):
        r = randint(0,100)
        if r > userStat[4]:
            return False
        else:
            return True
        
        
        

userStat = [170,12,13,9,4]
Ability = {"철갑" : 3}
Destiny = ""

skills = ["공격","방어"]



    



sft()   
print("<잿빛 숲>\n")
print(" 당신은 잿빛으로 뒤덮인 숲속에서 깨어났다. 기억을 더듬어 보니 다른 원정대원들과 함께")
print("눈사태에 휘말렸던 게 생각난다. 눈을 털어내고 주변을 둘러보자 말라죽은 나무들만이 서 있다.")
msft()
print("몸에 알 수 없는 힘이 깃든다.")
pak()
DiceRoll = random.sample(range(0,len(DesIndex)),3)
print("<<<운명을 선택하세요.>>>")
print(f"1. {DesIndex[DiceRoll[0]]}\n2. {DesIndex[DiceRoll[1]]}\n3. {DesIndex[DiceRoll[2]]}")
choose = input()


    

###랜덤인카운터
#damdown = 0






###
#print(skills)
#act = input("어떻게 할까?")

#if act.isdigit():
#    act = skills[int(act)-1]

#if act == "공격":
#    if dogde:
#        print("적이 공격을 회피했습니다.")
#    else:
#        enemyhp -= (userStat(1) - damdown)
#elif act == "수비":
#    userShield: userStat(2) * 2.5
# Out:
# ...
# <잿빛 숲>
#
#  당신은 잿빛으로 뒤덮인 숲속에서 깨어났다. 기억을 더듬어 보니 다른 원정대원들과 함께
# 눈사태에 휘말렸던 게 생각난다. 눈을 털어내고 주변을 둘러보자 말라죽은 나무들만이 서 있다.
# ----------------------------------------------------------------------------------------------------
# 몸에 알 수 없는 힘이 깃든다.
#
#
#
# >>>press any key
# ...
# ㅛ
# <<<운명을 선택하세요.>>>
# 신세대 독술사 : 전투 시작 시 적에게 중독을 10 부여합니다.
# 암흑가 출신 : 간파 +3Lv, 방어력 +2
# 곰의 영혼 : 매 턴마다 체력이 4 증가됩니다.

# %%
t = Text()
# Out:
# None

# %%
class aPhase:
    #철갑
    #가시
    #흡혈
    #독액
    #압도
    #증폭
    #파괴자
    #연격

class sPhase:
    #정밀
    #괴력
    #행운
    #생존
    #발화
    
    
    
    
class mPhase:
    #성장
    #격노
    #독안개
    #필살
    #충전
    #감전
    
class bPhase:
    #인내
    #역장
    #기습
    #선공
    #불굴
    
class pPhase:
    #민첩
    #신속
    #수호자
    
    
class ePhase:
