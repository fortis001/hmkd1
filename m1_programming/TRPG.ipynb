# %%
import random, time

userName = input("당신의 이름을 입력하세요.\n>")
statDiceRoll = "n"
userStat = []
run = 1
while statDiceRoll == "n":
    i = 0
    del userStat[:]
    while i < 6:
        diceStat = random.randint(3,12)
        userStat.append(diceStat)
        i += 1
    stre = userStat[0]
    dex = userStat[1]
    inte = userStat[2]
    kar = userStat[3]
    hel = userStat[4]
    wis = userStat[5]
    mhp = int(hel/3)
    hp = mhp
    mmp = int(wis/3)
    mp = mmp
    print("주사위를 굴려 당신의 기본 능력치를 설정합니다. 확정하시겠습니까? [y/n]")
    print(f'힘   : {stre} 민첩 : {dex}\n지능 : {inte} 위엄 : {kar}\n건강 : {hel} 지혜 : {wis}\n체력 : {mhp} 정신 : {mmp}')
    statDiceRoll = input()

                
episode = ["ep1","ep2"]
weapons = { "낡은 검" : [1.3, stre, 0, 0, 100 , "1.3힘"],
            "엘로이 아망 소드" : [1.2, stre, 0.6, dex, 180, "1.2힘 0.6민"], 
            "숏보우" : [1.2, dex, 0.6, stre, 120, "1.2민 0.6힘"],
            "저주받은 지팡이" : [2, wis , 0.6 ,inte, 500, "2혜 0.6지"],
            "야만의 몽둥이" : [3.4, stre, 0, 0, 1100, "3.4힘"]
           }

items1 = {"빨간 포션" : [2, 0]}
items2 = {"빨간 포션" : [hp , 0]}

mov = ""
        
    
def sft():
    print("="*100)

def msft():
    print("-"*100)

def inp():
    user = input()
    while True:
        if user == "menu":
            callMenu()
            user = input()
        else:
            break
    return user

def rol():
    global diceRoll, mov
    if hp == 0 or mp == 0:
        mov = "deadend"
        return mov
    elif len(episode)>0:
        diceRoll = random.randint(0,len(episode)-1)
        mov = episode[diceRoll]
        del episode[diceRoll]
        return mov
    else:
        mov = "ending"
        return mov

def pak():
    print("\n\n\n>>>press any key")
    print("="*100)
    while True:
        N = input()
        if N == "menu":
            callMenu()
        else:
            break

def Per(a,b):
    Percent = 10+round(a/b*100,1)
    if Percent > 100:
        Percent = 100
    return Percent

def BPer(a):
    global power
    Percent = 10+round(power/a*100,1)
    if Percent > 100:
        Percent = 100
    return Percent

def Pan():
    n = round(random.uniform(0,100),1)
    if n < pe:
        return True
    else:
        return False
    
def Loading():
    time.sleep(0.5)
    print("■", end = "")
    time.sleep(0.5)
    print("■", end = "")
    time.sleep(0.5)
    print("■")
    time.sleep(1)
    
def CHP(a):
    global hp, mhp
    if a > 0:
        b = "+"
        if hp < mhp:
            hp += a
    else:
        b = ""
        hp += a
    print(f"체력{b}{a}, 현재 체력:{hp}")
    return hp
        
def CMP(a):
    global mp,mmp
    if a > 0:
        b = "+"
        if mp < mmp:
            mp += a
    else:
        b = ""
        mp += a
    print(f"mp{b}{a}, 현재 정신력:{mp}")
    return mp

def powCal():
    power = weapons.get(weapon)[0]*weapons.get(weapon)[1] + weapons.get(weapon)[2]*weapons.get(weapon)[3]
    return power

def callMenu():
    msft()
    print("<메뉴>\n\n")
    global weapon, power, equip, inventory
    while True:
        print("1. 내 정보 2. 장비 교체\n3.인벤토리 4. 메뉴 나가기")
        g = input()
        if g == "1":
            print(f'힘   : {stre} 민첩 : {dex}\n지능 : {inte} 위엄 : {kar}\n건강 : {hel} 지혜 : {wis}')
            print(f"\n\n체력 : {hp}/{mhp} 정신 : {mp}/{mmp}")
            print(f"현재 경험치 : {exp}/{5+lv}")
            print(f"장착 무기 : {weapon}, 전투력 {power:.1f}")
        elif g == "2":
            print(equip)
            while True:
                w = input("사용할 아이템 명을 입력하세요. 뒤로 가기 위해선 아무 키나 입력하세요.")
                if w in equip:
                    equip.append(weapon)
                    weapon = w
                    equip.remove(w)
                    power = powCal()
                    print(f"전투력 : {power:.1f}")
                    print(equip)
                else:
                    break   
        else:
            print("메뉴를 종료합니다.")
            break
    
def expUp(a):
    global exp, lv, userStat, stre, dex, inte, kar, hel, wis, mhp, mmp, hp, mp
    exp += a
    if exp >= 5+lv:
        exp = exp - 5 - lv
        lv += 1
        ustat = 4
        print("레벨이 올랐습니다. 증가시킬 스탯을 선택해 주십시오. 남은 분배 스탯 : 4")
        print("1. 힘  2. 민첩\n3. 지능 4. 위엄\n5. 건강 6. 지혜")
        li = ["힘","민첩","지능","위엄","건강","지혜"]
        while ustat != 0:
            u = int(input()) - 1
            try:
                userStat[u] += 1
            except:
                print("오류 발생")
                u = 0
                ustat += 1
                continue
            print(f"현재 {userStat[u]}, 남은 분배 스탯:{ustat-1}")
            ustat -= 1
        stre = userStat[0]
        dex = userStat[1]
        inte = userStat[2]
        kar = userStat[3]
        hel = userStat[4]
        wis = userStat[5]
        if int(hel/3) > mhp:
            print("최대 Hp 증가!")
            hp = hp + (int(hel/3) - mhp)
            mhp = mhp + (int(hel/3) - mhp)
        if int(wis/3) > mmp:
            print("최대 Mp 증가!")
            mp = mp + (int(wis/3) - mmp)
            mmp = mmp + (int(wis/3) - mmp)
    return exp, lv, userStat, stre, dex, inte, kar, hel, wis, mhp, mmp, hp, mp
    

print("모험을 시작합니다.")
### 프롤로그
sft()
print('''<위대한 모험가>\n\n\n 웅장한 나팔소리와 함꼐 한 사람이 단상으로 천천히 올라갔다. 그 사람은 왕의 앞에 천천히 무릎을 꿇었다.\n
"자네의 모험을 온 국민이 기억할 걸세. 모두 보아라! 이 자가 이 나라의 영웅이다!"\n
왕의 외침과 함께 관중들의 환호가 터져나왔다. 당신은 그 날부터, 명예로운 모험가가 되겠다는 꿈을 품었다.\n
몇 년의 세월이 흘렀으나, 그 기억은 여전히 당신에게 남아 모험을 떠나게 만들었다.''')

lv = 1
exp = 0
weapon = "낡은 검"
power = weapons.get(weapon)[0]*weapons.get(weapon)[1] + weapons.get(weapon)[2]*weapons.get(weapon)[3]
inventory = []
equip = []

pak()
rol()
while True:
    if mov == "ending":
        print("당신은 수많은 모험을 끝내고 마침내 전설의 모험자가 되었습니다. 축하합니다")
        break
    if mov == "deadend":
        print("당신은 힘이 다하여 쓰러졌다...")
        break
### 폐허와 해골
    if mov == "ep1":
        sft()
        print(''' <폐허와 해골>\n\n\n당신은 무너진 폐허를 발견했다. 폐허에는 하얀 백골들이 널브러져 있고,\n그 사이로 칼 한자루가 꽂혀 있는 게 보인다.''')
        msft()
        pe = Per(wis, 19)
        print(f'''1.칼을 챙긴다. : (지혜)성공확률 {pe}%\n2.명복을 빈다.\n3.뼈를 걷어찬다.''')
        sft()
        a=inp()
        if a== "1":
            Loading()
            if Pan() == True:
                print('''당신은 백골 사이에 꽂힌 검을 손에 넣었다. 당신은 기분 좋게\n검을 등에 맨 채 폐허를 떠났다.''')
                msft()
                print("엘로이 아망 소드 +1")
                equip.append("엘로이 아망 소드")
                pak()
                rol()
            else:
                print('''당신은 백골 사이에 꽂힌 검을 얻기 위해 손을 뻗었으나,\n갑작스럽게 해골 하나가 일어나 당신의 손을 물었다.\n당신은 아픈 손을 움켜쥐며 한 발자국 물러나 전투를 준비했다.''')
                msft()
                hp = CHP(-1)
                if hp != 0:
                    pe = BPer(29)
                    print(f"전투 시작\n당신의 전투력 : {power:.1f} 승리 확률:{pe}%")
                    pak()
                    if Pan() == True:
                        Loading()
                        print("당신은 스켈레톤을 완전히 박살내 버렸고, 낡은 검을 손에 넣었다.")
                        msft()
                        print("엘로이 아망 소드 +1\n경험치 +2")
                        expUp(2)
                        equip.append("엘로이 아망 소드")
                        pak()
                        rol()
                    else:
                        Loading()
                        print("당신은 전투에서 패배했고, 아픈 몸을 이끌고 다시 여행을 나섰다.\n경험치+2")
                        expUp(2)
                        msft()
                        hp = CHP(-1)
                        pak()
                        rol()
                else:
                    rol()
        elif a =="2":
            print('''당신은 널브러진 뼈를 보며 조용히 명복을 빌었다...''')
            msft()
            mp = CMP(1)
            pak()
            rol()
        else:
            print('''당신은 널브러진 뼈를 걷어찼다. 그러자 옆의 해골들이 갑작스럽게 벌떡 일어나\n당신에게 덤벼들었다.''')
            msft()
            pe = BPer(29)
            print(f"전투 시작\n당신의 전투력 : {power:.1f} 승리 확률:{pe}%")
            pak()
            Loading()
            if Pan():
                print("당신은 덤벼드는 스켈레톤을 완전히 박살내 버리고, 후련한 듯 다시 여행을 떠났다.\n경험치+3")
                expUp(3)
                pak()
                rol()
            else:
                print("당신은 전투에서 패배했고, 아픈 몸을 이끌고 다시 여행을 나섰다.\n경험치+3")
                expUp(3)
                msft()
                hp = CHP(-1)
                pak()
                rol()

            
###            
    if mov == "ep2":
        sft()
        print("<수상한 노인>\n\n")
        print('''당신은 누군가 부르는 소리를 들었다.\n\n"거기 아가야..."\n\n그 소리는 노파의 목소리였는데, 마치 당신의 머릿속에서 말을 거는 것 같았다.''')
        print('''목소리가 어디서 나오는지 찾으려 두리번 거리는 당신에게 다시 목소리가 들렸다.\n\n"오른쪽...여기야 여기..."''')
        print('''거대한 무덤처럼 쌓여있는 나무판자와 쓰레기들 틈에서 누군가 당신을 부르고 있었다.\n당신이 쓰레기더미 사이를 살피자''')
        print('''죄수복을 입고 수갑과 족쇄를 찬 노파가 쪼그려 앉아 있었다.\n그녀는 자신을 풀어달라고 한다.''')
        msft()
        print("1.무엇을 줄 수 있나?\n2.구속을 풀어준다.\n3.그냥 놔두고 간다.\n4.치안대에 넘긴다.")
        sft()
        a = inp()
        if a == "1":
            print('''"음... 글쎼? 아마도 내 사랑?... 아하하하하하!!"\n\n노파는 잠시 웃더니 말을 이었다.''')
            print('''"지금 딱히 줄 수 있는 건 없는데, 구속이 풀리면 뭔가 생길거야."\n\n그녀는 활짝 웃으며 당신을 바라본다. 주름진 얼굴이 더욱 주름져 보였다.''')
            msft()
            print("1.구속을 풀어준다.\n2.그냥 놔두고 간다.\n3.치안대에 넘긴다.")
            sft()
            b = inp()
            if b == "1":
                Loading()
                print('''"고맙구나 아가야. 이제야 좀 살 것 같네!"\n\n 그녀는 잠시 기지개를 켜더니 순식간에 아름다운 젊은 여성으로 변했다.''')
                print('''그러곤 허공에 손을 그어 공간을 여는 포탈을 만들어냈다.\n\n"휴! 하마터면 화형당할 뻔 했네. 나중에 또 보자꾸나!"\n그녀는 포탈 속으로 사라졌다.''')
                pak()
                rol()
            elif b == "2":
                print("쓸데없는 곳에 쓸 시간은 없지.\n당신은 그렇게 중얼거리며 노파를 뒤로한 채 떠났다.")
                pak()
                rol()
            else:
                print('''"날 치안대에 넘기려고?"\n\n노파는 분노에 찬 얼굴을 지었다.\n"이대로 내가 포기할 것 같아?"\n\n노파가 덤벼들었다.''')
                msft()
                pe = BPer(32)
                print(f"전투 시작\n당신의 전투력 : {power:.1f} 승리 확률:{pe}%")
                pak()
                Loading()
                if Pan() == True:
                    print("당신은 달려드는 노파와 싸워 승리를 거뒀다.\n쓰러진 노파는 잠깐 마녀의 모습이 되었다가, 순식간에 먼지가 되어 사라졌다.")
                    print("경험치 +6")
                    expUp(6)
                    pak()
                    rol()
                else:
                    print("노파는 순식간에 마녀로 변해 마법을 퍼부었다.\n당신은 부리나케 줄행랑쳤지만, 몸 한구석에 맞은 화염구가 씻을 수 없는 상처를 남겼다.")
                    print("경험치 +6")
                    expUp(6)
                    msft()
                    hp = CHP(-1)
                    pak()
                    rol()
        elif a == "2":
            Loading()
            print('''"고맙구나 아가야. 이제야 좀 살 것 같네!"\n\n 그녀는 잠시 기지개를 켜더니 순식간에 아름다운 젊은 여성으로 변했다.''')
            print('''그러곤 허공에 손을 그어 공간을 여는 포탈을 만들어냈다.\n\n"휴! 하마터면 화형당할 뻔 했네. 나중에 또 보자꾸나!"\n그녀는 포탈 속으로 사라졌다.''')
            pak()
            rol()
        elif a == "3":
            print("쓸데없는 곳에 쓸 시간은 없지.\n당신은 그렇게 중얼거리며 노파를 뒤로한 채 떠났다.")
            pak()
            rol()
        else:
            print('''"날 치안대에 넘기려고?"\n\n노파는 분노에 찬 얼굴을 지었다.\n"이대로 내가 포기할 것 같아?"\n\n노파가 덤벼들었다.''')
            msft()
            pe = BPer(32)
            print(f"전투 시작\n당신의 전투력 : {power:.1f} 승리 확률:{pe}%")
            pak()
            Loading()
            if Pan() == True:
                print("당신은 달려드는 노파와 싸워 승리를 거뒀다.\n쓰러진 노파는 잠깐 마녀의 모습이 되었다가, 순식간에 먼지가 되어 사라졌다.")
                print("경험치 +6")
                expUp(6)
                pak()
                rol()
            else:
                print("노파는 순식간에 마녀로 변해 마법을 퍼부었다.\n당신은 부리나케 줄행랑쳤지만, 몸 한구석에 맞은 화염구가 씻을 수 없는 상처를 남겼다.")
                print("경험치 +6")
                expUp(6)
                msft()
                hp = CHP(-1)
                pak()
                rol()
                

###
"""
    if mov == "ep3":
        print("<진흙 더미의 시체>\n\n\n")
        print('당신은 진흙 더미에 반쯤 파묻힌 철창을 발견했다. 그 안에는 말라 비틀어진 시체가 하나 있었다.')
        print("썩는 악취에 당신은 머리가 어질한 느낌을 받았다.")
        msft()
        pe = Per(dex, 23)
        print(f"1.지나간다. : (민첩)성공확률 {pe}%\n시신을 매장한다.")
        sft()
        a = inp()
        if a == "1":
            if Pan() == True:
                print("당신은 있는 힘껏 달려 그곳에서 벗어났다. 꽤 멀리 떨어졌음에도, 아직 악취가 코에 맴도는 것 같다.")
                pak()
                rol()
            else:
"""              
 
d = 1
# Out:
# 당신의 이름을 입력하세요.
# >and
# 주사위를 굴려 당신의 기본 능력치를 설정합니다. 확정하시겠습니까? [y/n]
# 힘   : 11 민첩 : 5
# 지능 : 9 위엄 : 5
# 건강 : 9 지혜 : 12
# 체력 : 3 정신 : 4
# y
# 모험을 시작합니다.
# ...
# <위대한 모험가>
#
#
#  웅장한 나팔소리와 함꼐 한 사람이 단상으로 천천히 올라갔다. 그 사람은 왕의 앞에 천천히 무릎을 꿇었다.
#
# "자네의 모험을 온 국민이 기억할 걸세. 모두 보아라! 이 자가 이 나라의 영웅이다!"
#
# 왕의 외침과 함께 관중들의 환호가 터져나왔다. 당신은 그 날부터, 명예로운 모험가가 되겠다는 꿈을 품었다.
#
# 몇 년의 세월이 흘렀으나, 그 기억은 여전히 당신에게 남아 모험을 떠나게 만들었다.
#
#
#
# >>>press any key
# ...
#
# ...
#  <폐허와 해골>
#
#
# 당신은 무너진 폐허를 발견했다. 폐허에는 하얀 백골들이 널브러져 있고,
# 그 사이로 칼 한자루가 꽂혀 있는 게 보인다.
# ----------------------------------------------------------------------------------------------------
# 1.칼을 챙긴다. : (지혜)성공확률 73.2%
# 2.명복을 빈다.
# 3.뼈를 걷어찬다.
# ...
# 1
# ■■■
# 당신은 백골 사이에 꽂힌 검을 얻기 위해 손을 뻗었으나,
# 갑작스럽게 해골 하나가 일어나 당신의 손을 물었다.
# 당신은 아픈 손을 움켜쥐며 한 발자국 물러나 전투를 준비했다.
# ----------------------------------------------------------------------------------------------------
# 체력-1, 현재 체력:2
# 전투 시작
# 당신의 전투력 : 14.3 승리 확률:59.3%
#
#
#
# >>>press any key
# ...
#
# ■■■
# ...

# %%
import random
stre = 6
dex = 6
wis = 6
inte = 6
weaponl = ["낡은 검", "엘로이 아망 소드", "숏보우", "저주받은 지팡이", "야만의 몽둥이"]
weapons = { "낡은 검" : [1.3, stre, 0, 0, 100 , "   1.3힘"],
            "엘로이 아망 소드" : [1.2, stre, 0.6, dex, 180, "   1.2힘 0.6민"], 
            "숏보우" : [1.2, dex, 0.6, stre, 120, "   1.2민 0.6힘"],
            "저주받은 지팡이" : [2, wis , 0.6 ,inte, 500, "   2혜 0.6지"],
            "야만의 몽둥이" : [3.4, stre, 0, 0, 1100, "   3.4힘"]
            }
equip = []
class Trade:
    def __init__(self):
        itemnum = random.randint(2,5)
        s = random.sample(weaponl, itemnum) # ["낡은 검", "숏보우" ...]
        i_list = {}
        i = 0
        while i < itemnum:
            a = weapons.get(s[i]) # [1.3 stre m 0 ,0 ,100 , "설명"]
            i_list[s[i]] = f"{s[i]} : ${a[5]}\t{a[6]}"
            i += 1
        for i in i_list:
            print(i_list(get(i)))
        print("-"*100)
        
    #def buy(self,num):

# %%
s = Trade()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4884\397002049.py in <module>
# ----> 1 s = Trade()
#
# ~\AppData\Local\Temp\ipykernel_4884\1016959929.py in __init__(self)
#      20         while i < itemnum:
#      21             a = weapons.get(s[i]) # [1.3 stre m 0 ,0 ,100 , "설명"]
# ---> 22             i_list[s[i]] = f"{s[i]} : ${a[5]}\t{a[6]}"
#      23             i += 1
#      24         for i in i_list:
#
# IndexError: list index out of range

# %%
방패 : 얼마 : 능력
창 : 얼마 : 능력
