# %%
#####교통수단
car = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 3, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 5, "커다란가?" : 2, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 4, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 4,
       "단순 이동 외의 목적이 있나?" : 2, "무언가를 운반하는가?" : 2}
motorcycle = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 3, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 5, "커다란가?" : 1, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 1, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 5,
       "단순 이동 외의 목적이 있나?" : 1, "무언가를 운반하는가?" : 1}
bycycle = {"시속 50km 이상?": 1, "인력을 이용?" : 5, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 1, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 5, "커다란가?" : 1, "물과 관련이 있나?" : 1, "연료가 필요?" : 1, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 1, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 5,
       "단순 이동 외의 목적이 있나?" : 1, "무언가를 운반하는가?" : 1}
truck = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 4, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 5, "커다란가?" : 4, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 1, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 5, "무언가를 운반하는가?" : 5}
tank = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 2, "비싼가?" : 5, "기계 동력?" : 5, 
       "바퀴가 있나?" : 3, "직접 운전하나?" : 5, "커다란가?" : 5, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 4, "하늘에 뜨는가?" : 1, "전투 목적?" : 5, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 5, "무언가를 운반하는가?" : 1}
raft = {"시속 50km 이상?": 1, "인력을 이용?" : 5, "동물과 관련?" : 1, "핸들이 있나?" : 1, "비싼가?" : 1, "기계 동력?" : 1, 
       "바퀴가 있나?" : 1, "직접 운전하나?" : 5, "커다란가?" : 1, "물과 관련이 있나?" : 5, "연료가 필요?" : 1, 
       "바람과 관련?" : 5, "여러 사람이 동시에 이용?" : 3, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 3, "무언가를 운반하는가?" : 4}
rickshaw = {"시속 50km 이상?": 1, "인력을 이용?" : 5, "동물과 관련?" : 1, "핸들이 있나?" : 1, "비싼가?" : 1, "기계 동력?" : 1, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 5, "커다란가?" : 2, "물과 관련이 있나?" : 1, "연료가 필요?" : 1, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 1, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 2, "무언가를 운반하는가?" : 2}
bus = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 4, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 1, "커다란가?" : 4, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 5, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 1, "무언가를 운반하는가?" : 5}
subway = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 1, "비싼가?" : 5, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 1, "커다란가?" : 5, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 5, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 1, "무언가를 운반하는가?" : 5}
taxi = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 3, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 1, "커다란가?" : 2, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 2, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 1, "무언가를 운반하는가?" : 5}
balloon = {"시속 50km 이상?": 1, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 1, "비싼가?" : 4, "기계 동력?" : 1, 
       "바퀴가 있나?" : 1, "직접 운전하나?" : 1, "커다란가?" : 5, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 5, "여러 사람이 동시에 이용?" : 4, "하늘에 뜨는가?" : 5, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 3, "무언가를 운반하는가?" : 3}
airplane = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 3, "비싼가?" : 5, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 1, "커다란가?" : 5, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 4, "여러 사람이 동시에 이용?" : 5, "하늘에 뜨는가?" : 5, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 3, "무언가를 운반하는가?" : 5}
fighter = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 3, "비싼가?" : 5, "기계 동력?" : 5, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 5, "커다란가?" : 5, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 4, "여러 사람이 동시에 이용?" : 1, "하늘에 뜨는가?" : 5, "전투 목적?" : 5, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 5, "무언가를 운반하는가?" : 1}
helicopter = {"시속 50km 이상?": 5, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 3, "비싼가?" : 5, "기계 동력?" : 5, 
       "바퀴가 있나?" : 1, "직접 운전하나?" : 3, "커다란가?" : 5, "물과 관련이 있나?" : 1, "연료가 필요?" : 5, 
       "바람과 관련?" : 4, "여러 사람이 동시에 이용?" : 3, "하늘에 뜨는가?" : 5, "전투 목적?" : 3, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 3, "무언가를 운반하는가?" : 3}
boat = {"시속 50km 이상?": 3, "인력을 이용?" : 1, "동물과 관련?" : 1, "핸들이 있나?" : 5, "비싼가?" : 3, "기계 동력?" : 5, 
       "바퀴가 있나?" : 1, "직접 운전하나?" : 5, "커다란가?" : 2, "물과 관련이 있나?" : 5, "연료가 필요?" : 5, 
       "바람과 관련?" : 3, "여러 사람이 동시에 이용?" : 3, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 3,
       "단순 이동 외의 목적이 있나?" : 4, "무언가를 운반하는가?" : 3}
carriage = {"시속 50km 이상?": 1, "인력을 이용?" : 1, "동물과 관련?" : 5, "핸들이 있나?" : 1, "비싼가?" : 3, "기계 동력?" : 3, 
       "바퀴가 있나?" : 5, "직접 운전하나?" : 3, "커다란가?" : 4, "물과 관련이 있나?" : 1, "연료가 필요?" : 1, 
       "바람과 관련?" : 1, "여러 사람이 동시에 이용?" : 3, "하늘에 뜨는가?" : 1, "전투 목적?" : 1, "경기에 사용되나?" : 1,
       "단순 이동 외의 목적이 있나?" : 3, "무언가를 운반하는가?" : 5}
horse = {"시속 50km 이상?": 4, "인력을 이용?" : 1, "동물과 관련?" : 5, "핸들이 있나?" : 1, "비싼가?" : 3, "기계 동력?" : 1, 
       "바퀴가 있나?" : 1, "직접 운전하나?" :
"동그란 모양인가?" : 1,"단단한가?" : 5,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 2, "주먹보다 큰가?" : 3,
        "쓴맛이 나는가?" : 5,"수분이 많은가?" : 5,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,"길쭉한 모양인가?" : 5,
        "뿌리채소인가?" : 1,"향이 강한가?" : 5,"햄버거 재료인가?" : 1,"여름 채소인가?" : 4,"잎을 먹는가?" : 4,
        "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 1}
cauliflower = {"생으로도 먹는가?" : 4,"동그란 모양인가?" : 2,"단단한가?" : 4,"겉이 하얀색인가?" : 5,"껍질도 먹는가?" : 1, 
               "주먹보다 큰가?" : 3, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 1,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
               "길쭉한 모양인가?" : 1, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 1,"여름 채소인가?" : 1,
               "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 4}
asparagus = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 1,"단단한가?" : 1,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 2, 
             "주먹보다 큰가?" : 2, "쓴맛이 나는가?" : 4,"수분이 많은가?" : 1,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
             "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 1,"향이 강한가?" : 2,"햄버거 재료인가?" : 1,"여름 채소인가?" : 1,
             "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 5}
pumpkin = {"생으로도 먹는가?" : 2,"동그란 모양인가?" : 2,"단단한가?" : 5,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 1, 
        "주먹보다 큰가?" : 5, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 5,"겉이 초록색인가?" : 1,"속이 노란색인가?" : 5,
        "길쭉한 모양인가?" : 2, "뿌리채소인가?" : 1,"향이 강한가?" : 2,"햄버거 재료인가?" : 1,"여름 채소인가?" : 5,
        "잎을 먹는가?" : 3, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 5}
radish = {"생으로도 먹는가?" : 3,"동그란 모양인가?" : 1,"단단한가?" : 5,"겉이 하얀색인가?" : 5,"껍질도 먹는가?" : 1, 
        "주먹보다 큰가?" : 5, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 5,"겉이 초록색인가?" : 4,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 5,"향이 강한가?" : 2,"햄버거 재료인가?" : 1,"여름 채소인가?" : 2,
        "잎을 먹는가?" : 2, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 3}
cucumber = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 1,"단단한가?" : 3,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 4, 
            "주먹보다 큰가?" : 4, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 5,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
            "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 1,"여름 채소인가?" : 5,
            "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 1}
lettuce = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 5,"단단한가?" : 1,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 3, 
        "주먹보다 큰가?" : 5, "쓴맛이 나는가?" : 4,"수분이 많은가?" : 5,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 1, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 5,"여름 채소인가?" : 4,
        "잎을 먹는가?" : 5, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 4}
tomato = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 5,"단단한가?" : 1,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 5, 
        "주먹보다 큰가?" : 3, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 5,"겉이 초록색인가?" : 1,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 1, "뿌리채소인가?" : 1,"향이 강한가?" : 2,"햄버거 재료인가?" : 5,"여름 채소인가?" : 5,
        "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 5}
sprouts = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 1,"단단한가?" : 1,"겉이 하얀색인가?" : 5,"껍질도 먹는가?" : 5, 
        "주먹보다 큰가?" : 1, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 5,"겉이 초록색인가?" : 1,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 1,"여름 채소인가?" : 1,
        "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 1}
spinach = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 1,"단단한가?" : 1,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 3, 
        "주먹보다 큰가?" : 1, "쓴맛이 나는가?" : 5,"수분이 많은가?" : 5,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 4, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 1,"여름 채소인가?" : 1,
        "잎을 먹는가?" : 5, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 4}
pimento = {"생으로도 먹는가?" : 1,"동그란 모양인가?" : 1,"단단한가?" : 2,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 4, 
        "주먹보다 큰가?" : 2, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 2,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 1, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 1,"여름 채소인가?" : 5,
        "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 1}
eggplant = {"생으로도 먹는가?" : 1,"동그란 모양인가?" : 1,"단단한가?" : 3, "겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 3, 
            "주먹보다 큰가?" : 3, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 4,"겉이 초록색인가?" : 1,"속이 노란색인가?" : 1,
            "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 1,"향이 강한가?" : 4,"햄버거 재료인가?" : 1,"여름 채소인가?" : 5,
            "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 1}
spring_onion = {"생으로도 먹는가?" : 3,"동그란 모양인가?" : 1,"단단한가?" : 1,"겉이 하얀색인가?" : 5,"껍질도 먹는가?" : 1, 
                "주먹보다 큰가?" : 4, "쓴맛이 나는가?" : 4,"수분이 많은가?" : 4,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
                "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 5,"향이 강한가?" : 5,"햄버거 재료인가?" : 1,"여름 채소인가?" : 1,
                "잎을 먹는가?" : 5, "매운 맛이 나는가?" : 5,"단맛이 나는가?" : 1}
pepper = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 1,"단단한가?" : 2,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 5, 
        "주먹보다 큰가?" : 1, "쓴맛이 나는가?" : 1,"수분이 많은가?" : 3,"겉이 초록색인가?" : 4,"속이 노란색인가?" : 1,
        "길쭉한 모양인가?" : 5, "뿌리채소인가?" : 1,"향이 강한가?" : 2,"햄버거 재료인가?" : 1,"여름 채소인가?" : 5,
        "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 5,"단맛이 나는가?" : 1}
broccoli = {"생으로도 먹는가?" : 5,"동그란 모양인가?" : 1,"단단한가?" : 4,"겉이 하얀색인가?" : 1,"껍질도 먹는가?" : 1, 
            "주먹보다 큰가?" : 1, "쓴맛이 나는가?" : 4,"수분이 많은가?" : 2,"겉이 초록색인가?" : 5,"속이 노란색인가?" : 1,
            "길쭉한 모양인가?" : 1, "뿌리채소인가?" : 1,"향이 강한가?" : 1,"햄버거 재료인가?" : 1,"여름 채소인가?" : 1,
            "잎을 먹는가?" : 1, "매운 맛이 나는가?" : 1,"단맛이 나는가?" : 1}

#####과일
apple = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
orange = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
strawberry = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
lemon = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
watermelon = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
melon = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
banana = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
pineapple = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
grape = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
cherry = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
peach = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
mango = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
kiwi = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
pear = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
avocado = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
blueberry = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
persimmon = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
durian = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}
chamoe = {"속이 하얀색인가?" : 5,"속이 붉은색인가?" : 1,"주먹보다 작은가?" : 3,"무거운가?" : 2,"속이 노란색인가?" : 4,
        "부드러운가?": 1,"겉이 붉은색인가?" : 5,"속이 초록색인가?" : 1,"껍질도 먹는가?" : 4,"껍질이 단단한가?" : 1,
        "씨도 먹는가?" : 1,"비싼가?" : 1,"씨가 많은가?" : 1,"새콤한 맛인가?" : 4,"동그란 모양인가?" : 5,
         "달콤한 맛인가?" : 5, "수분이 많은가?" : 4}


#####시설
school = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
hospital = {"돈을 쓰는가?" : 5,"규모가 큰가?" : 4,"음식과 관련?" : 1,"하룻밤을 보낼 수 있나?" : 5,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 4,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 3,
          "많은가?": 3,"공공기관인가?" : 1,"외부인 출입을 허용하는가?" : 5}
park = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
museum = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
library = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
cinema = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
department = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
bank = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
restaurant = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
cafe = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
gym = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
pool = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
salon = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
zoo = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
aquarium = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
casino = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
plant = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
police = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
convenience ={"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
pub = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
racetrack = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}
fire_station = {"돈을 쓰는가?" : 1,"규모가 큰가?" : 3,"음식과 관련?" : 2,"하룻밤을 보낼 수 있나?" : 1,"뭔갈 보러 가는가?" : 1,
          "물건을 사러 가는가?" : 1,"어린이도 이용하는가?" : 5,"물과 관련?" : 1,"입장료가 있는가?" : 1,"밤에도 영업하는가?" : 3,
          "경비가 삼엄한가?" : 1, "동물과 관련이 있나?" : 1,"돈을 벌 수 있나?" : 1,"오래 머무는가?" : 4,
          "많은가?": 4,"공공기관인가?" : 5,"외부인 출입을 허용하는가?" : 1}

# %%
questions1 = ["시속 50km 이상?", "인력을 이용?", "동물과 관련?", "핸들이 있나?", "비싼가?", "기계 동력?", "바퀴가 있나?",
            "직접 운전하나?", "커다란가?", "물과 관련이 있나?", "연료가 필요?", "바람과 관련?", "여러 사람이 동시에 이용?",
            "하늘에 뜨는가?", "전투 목적?", "경기에 사용되나?","단순 이동 외의 목적이 있나?","무언가를 운반하는가?"]

ans1 = ["자동차", "오토바이", "자전거", "트럭", "탱크", "뗏목", "인력거", "버스", "지하철", "택시", "열기구", "비행기",
      "전투기", "헬리콥터", "모터보트", "마차", "말", "유람선", "소방차", "우주선", "트랙터", "잠수함", "구급차"]

ansd1 = {"자동차": car, "오토바이" : motorcycle, "자전거" : bycycle, "트럭" : truck, "탱크" : tank, "뗏목" :raft, "인력거" : rickshaw, 
         "버스" : bus, "지하철" : subway, "택시" : taxi, "열기구" : balloon, "비행기" : airplane, "전투기" : fighter, 
         "헬리콥터" : helicopter, "모터보트" : boat, "마차" : carriage, "말" : horse, "유람선" : cruise, 
         "소방차" : fire, "우주선" : spaceship, "트랙터" : tractor, "잠수함" : submarine, "구급차" : ambulance}


questions2 = ["신체 부위 일부가 긴가?","육식 동물인가?","위험한 동물인가?","가축인가?","식용인가?","포유류인가?",
             "몸집이 큰가?","특징적인 울음소리를 가지고 있나?","십이간지에 있나?","빠른가?","애완동물인가?","검은색인가?",
             "누런색인가?","물에 사는가?","날개가 있는가?","사족보행인가?","털이 많은가?","동물원 인기 동물인가?"]

ans2 = ["호랑이","사자","쥐","코끼리","늑대","개","고양이","뱀","말","기린","원숭이","곰","펭귄","인간",
        "소","돼지","토끼","양","닭","오리","독수리","코뿔소","거북이","물고기"]

ansd2 = {}


questions3 = ["생으로도 먹는가?","동그란 모양인가?","단단한가?","겉이 하얀색인가?","껍질도 먹는가?","주먹보다 큰가?",
              "쓴맛이 나는가?","수분이 많은가?","겉이 초록색인가?","속이 노란색인가?","길쭉한 모양인가?",
              "뿌리채소인가?","향이 강한가?","햄버거 재료인가?","여름 채소인가?","잎을 먹는가?",
              "매운 맛이 나는가?","단맛이 나는가?"]

ans3 = ["당근","양파","마늘","감자","고구마","샐러리","컬리플라워","아스파라거스","호박","무","오이","양상추","토마토",
        "콩나물","시금치","피망","가지","파","고추","브로콜리"]

ansd3 = {}


questions4 = ["속이 하얀색인가?","속이 붉은색인가?","주먹보다 작은가?","무거운가?","속이 노란색인가?",
              "부드러운가?","겉이 붉은색인가?","속이 초록색인가?","껍질도 먹는가?","껍질이 단단한가?",
              "씨도 먹는가?","비싼가?","씨가 많은가?","새콤한 맛인가?","동그란 모양인가?","달콤한 맛인가?"]

ans4 = ["사과","오렌지","딸기","레몬","수박","멜론","바나나","파인애플","포도","체리","복숭아","망고","키위",
        "배","아보카도","블루베리","감","두리안","참외"]

ansd4 = {}


questions5 = ["돈을 쓰는가?","규모가 큰가?","음식과 관련?","하룻밤을 보낼 수 있나?","뭔갈 보러 가는가?","물건을 사러 가는가?",
              "어린이도 이용하는가?","물과 관련?","입장료가 있는가?","밤에도 영업하는가?","경비가 삼엄한가?",
              "동물과 관련이 있나?","돈을 벌 수 있나?","오래 머무는가?","많은가?","공공기관인가?","외부인 출입을 허용하는가?"]

ans5 = ["학교","병원","공원","박물관","도서관","영화관","백화점","은행","레스토랑","카페","체육관","수영장",
        "미용실","동물원","수족관","카지노","발전소","경찰서","편의점","주점","경마장","소방서"]


ansd5 = {}





Topic = ["교통수단","동물","채소","과일","시설"]

Tcans = {1 : "전혀 아니에요!",2 : "아닌 것 같아요.", 3: "글쎄요, 애매하네요.", 4: "그런 것 같아요.", 5 : "맞아요!"}

Fcans = {1 : "맞아요!",2 : "그런 것 같아요.", 3: "글쎄요, 애매하네요.", 4: "아닌 것 같아요.", 5 : "전혀 아니에요!"}

Jcans = {1 : "아... 다시 생각해 보면 전혀 아니에요!",
         2 : "아... 다시 생각해 보면 아닌 것 같아요.",
         3: "글쎄요, 애매하네요.",
         4: "아... 다시 생각해 보면 그런 것 같아요.",
         5 : "아... 다시 생각해 보면 맞아요!"}

# %%
import random, time

class Text:
    def sft(self):
        print("="*75)
        time.sleep(1)
    def msft(self):
        print("-"*75)
        time.sleep(1)
       

class System(Text):
    def __init__(self):
        self.J = 4
    def now_answer(self): # 정답 생성
        self.now_answer =  random.choice(ans)
        return self.now_answer
    
    def answer_sheet(self): # 대답 시트 생성
        self.answer_sheet = ansd.get(self.now_answer)
        return ansd.get(self.now_answer)
    
    def make_question(self): # 질문 생성
        T = Text()
        T.sft()
        if len(questions) > 3:
            self.a = random.sample(questions,3)
            print(f"1. {self.a[0]}\n2. {self.a[1]}\n3. {self.a[2]}")
            return self.a #질문 목록
        else:
            print("시간 초과! 게임 오버입니다.")
            return False
    
    def true_answer(self): # 대답을 듣고 선택지 생성
        T = Text()
        T.msft()
        if 4 < self.J:
            self.J = 4
        select = input(f"1. 알았어.\n2. 진실의 방으로.{self.J}/4\n>")
        correct = True
        if select == "1":
            self.J += 1
            return False
        elif select == "2":
            if self.J == 4:
                print("Q. 진실의 방으로.")
                self.J = 0
                return True
            else:
                print("아직 진실의 방으로를 사용할 수 없습니다.")
                self.J += 1
        else:
            print("정답이 아닙니다.")
            self.J += 1
        T.sft()
    
    def question_select(self): # 질문하기
        while True:
            if not self.make_question():
                return True
                break
            select = input("\n로그 입력 시 로그 출력\n리스트 입력 시 정답 리스트 출력\n포기 입력 시 포기\n>")
            if select.isdigit():
                select = int(select)
                break
            elif select == self.now_answer:
                print("정답입니다!")
                return True
                break
            elif select == "로그" or select == "log":
                i = 0
                while i < len(answered):
                    print(answered[i])
                    i += 1
            elif select == "리스트" or select == "list":
                print(ans)
            elif select == "포기":
                print("게임을 포기하셨습니다.")
                return True
                break
            else:
                print("정답이 아닙니다.")
        print(f"Q. {self.a[select-1]}")
        Acode = self.answer_sheet.get(self.a[select-1])
        questions.remove(self.a[select-1])
        del self.answer_sheet[self.a[select-1]]
        time.sleep(1)
        self.r = round(random.random(),2)
        if self.r <= 0.15:
            print("A. 기억이 나질 않아요....")
            answered.append(f"{self.a[select-1]} : 기억이 나질 않아요...")
            TF.append("미답변")
            if self.true_answer():
                print(f"A. {Jcans.get(Acode)}")
                answered.append(f"진실의 방으로 : {Jcans.get(Acode)}")
                TF.append("")
                time.sleep(1)
        elif 0.15 < self.r <= 0.35:
            print(f"A. {Fcans.get(Acode)}")
            answered.append(f"{self.a[select-1]} : {Fcans.get(Acode)}")
            TF.append("거짓")
            if self.true_answer():
                print(f"A. {Jcans.get(Acode)}")
                answered.append(f"진실의 방으로 : {Jcans.get(Acode)}")
                TF.append("")
                time.sleep(1)
        else:
            print(f"A. {Tcans.get(Acode)}")
            answered.append(f"{self.a[select-1]} : {Tcans.get(Acode)}")
            TF.append("진실")
            if self.true_answer():
                print("A. 제 말이 틀린 것 같진 않아요!")
                answered.append("진실의 방으로 : 제 말이 틀린 것 같진 않아요!")
                TF.append("")
                time.sleep(1)

                
class Menu(System):
    def Tutorial(self):
        T = Text()
        print("튜토리얼을 진행합니다.")
        T.sft()
        print("<<<상대방이 생각하는 디저트를 맞추자>>>")
        print("1. 단 음식인가?\n2. 파란색 음식인가?\n3. 부드러운 음식인가?\n4. 진실의 방으로")
        T.sft()
        print("이 게임은 상대방이 생각하는 것이 무엇인지 맞추는 게임입니다.\n")
        time.sleep(1)
        print("튜토리얼이므로, 정답을 미리 알고 있다고 가정하겠습니다. 정답은 '푸딩'입니다.\n")
        time.sleep(1)
        print("먼저 1번을 눌러 단 음식인지 질문을 해 봅시다.")
        while True:
            userSelect = input()
            if userSelect == "1":
                print("Q. 단 음식인가?")
                time.sleep(1)
                print("A. 맞아요!")
                T.sft()
                break
            else:
                print("1번을 입력해 봅시다.")
        print("컴퓨터가 대답을 했습니다. 대답엔 매우 그렇다, 그렇다, 중립, 아니다, 매우 아니다.\n5가지 종류가 있습니다.")
        time.sleep(1)
        print("다시 질문을 해보겠습니다. 이번엔 2번 질문을 해 봅시다.")
        print("1. 차가운 음식인가?\n2. 파란색 음식인가?\n3. 부드러운 음식인가?\n4. 진실의 방으로")
        T.sft()
        while True:
            userSelect = input()
            if userSelect == "2":
                print("Q. 파란색 음식인가?")
                time.sleep(1)
                print("A. 맞아요!")
                T.sft()
                break
            else:
                print("2번을 입력해 봅시다.")
        
        print('''컴퓨터가 대답을 했습니다만, 파란색 음식이냐는 질문에 "매우 그렇다"라고 대답을 하는군요.''' )
        time.sleep(1)
        print("컴퓨터는 가끔씩 거짓말로 답변을 하곤 합니다. 의심스러우니, 4번을 눌러 진실의 방으로 명령을 해보죠.")
        while True:
            userSelect = input()
            if userSelect == "4":
                print("Q. 진실의 방으로.")
                time.sleep(1)
                print("A. 아... 잘 생각해 보니 전혀 아니었어요.")
                T.sft()
                break
            else:
                print("4번을 입력해 봅시다.")
        
        print("진실의 방으로. 능력을 사용하자 컴퓨터가 진실한 답을 말했습니다. 다음, 3번 질문을 해 봅시다.")
        print("1. 차가운 음식인가? \n2. 딱딱한 음식인가?\n3. 부드러운 음식인가?\n4. 진실의 방으로")
        while True:
            userSelect = input()
            if userSelect == "3":
                print("Q. 부드러운 음식인가?")
                time.sleep(1)
                print("A. 기억이 나질 않아요...")
                T.sft()
                break
            else:
                print("3번을 입력해 봅시다.")

        print("가끔씩, 컴퓨터는 답변을 까먹기도 합니다.\n이 때 역시 진실의 방으로 명령을 사용하면 답변을 이끌어 낼 수 있습니다")
        time.sleep(1)
        print("하지만, 진실의 방으로 능력은 4번의 질문마다 한 번씩만 사용 가능하니, 신중하게 사용해 주세요.")
        print("이제 정답을 입력해 맞춰 봅시다. 정답은 푸딩 입니다.")

        while True:
            userSelect = input()
            if userSelect == "푸딩":
                print("정답을 맞췄습니다!")
                T.sft()
                break
            else:
                print("정답은 푸딩 입니다.")
        
        print("이것으로 튜토리얼을 마치겠습니다. 감사합니다.")
        
    def Maingame(self):
        S = System()
        T = Text()
        S.now_answer()
        S.answer_sheet()
        while True:
            S.question_select()
            if S.question_select():
                break
        print(f"정답 : {S.now_answer}")
        i = 0
        while i < len(answered):
            print(f"({TF[i]}){answered[i]}")
            i += 1
        T.sft()
    
    
class Game(Menu):
    def __init__(self):
        global TF, answered, questions
        T = Text()
        S = System()
        print("스무고개 게임에 온 것을 환영합니다.")
        M = Menu()
        while True:
            TF = []
            answered = []
            print("1. 시작\n2. 튜토리얼\n3. 종료")
            T.sft()
            userSelect = input()
            if userSelect == "1" or userSelect == "시작":
                while True:
                    topicSelect = input("주제를 고르세요.\n1. 교통수단\n2. 동물\n3. 채소\n4. 과일\n5. 시설\n")
                    if topicSelect == "1":
                        ans = ans1.copy()
                        ansd = ansd1.copy()
                        questions = questions1.copy()
                        break
                    elif topicSelect == "2":
                        print("아직 준비되지 않았습니다.")
                    elif topicSelect == "3":
                        print("아직 준비되지 않았습니다.")
                    elif topicSelect == "4":
                        print("아직 준비되지 않았습니다.")
                    elif topicSelect == "5":
                        print("아직 준비되지 않았습니다.")
                    else:
                        print("잘못된 입력입니다.")
                print(f"<<<상대방이 생각하는 {Topic[int(topicSelect)-1]}을 맞추자>>>")
                M.Maingame()
            elif userSelect == "2" or userSelect == "튜토리얼":
                M.Tutorial()
            elif userSelect == "3" or userSelect == "종료":
                print("게임을 종료합니다.")
                break
            else:
                print("잘못된 입력입니다. 다시 입력해 주세요.")

# %%
G = Game()
# Out:
# 스무고개 게임에 온 것을 환영합니다.
# 1. 시작
# 2. 튜토리얼
# 3. 종료
# ...
# 1
# 주제를 고르세요.
# 1. 교통수단
# 2. 동물
# 3. 채소
# 4. 과일
# 5. 시설
# 1
# <<<상대방이 생각하는 교통수단을 맞추자>>>
# ...
# 1. 커다란가?
# 2. 단순 이동 외의 목적이 있나?
# 3. 하늘에 뜨는가?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13736\2228957061.py in <module>
# ----> 1 G = Game()
#
# ~\AppData\Local\Temp\ipykernel_13736\3387691757.py in __init__(self)
#     247                         print("잘못된 입력입니다.")
#     248                 print(f"<<<상대방이 생각하는 {Topic[int(topicSelect)-1]}을 맞추자>>>")
# --> 249                 M.Maingame()
#     250             elif userSelect == "2" or userSelect == "튜토리얼":
#     251                 M.Tutorial()
#
# ~\AppData\Local\Temp\ipykernel_13736\3387691757.py in Maingame(self)
#     204         S.answer_sheet()
#     205         while True:
# --> 206             S.question_select()
# ...

# %%
print(questions)
# Out:
# ['시속 50km 이상?', '인력을 이용?', '동물과 관련?', '핸들이 있나?', '비싼가?', '기계 동력?', '바퀴가 있나?', '직접 운전하나?', '커다란가?', '물과 관련이 있나?', '연료가 필요?', '바람과 관련?', '여러 사람이 동시에 이용?', '하늘에 뜨는가?', '전투 목적?', '경기에 사용되나?', '단순 이동 외의 목적이 있나?', '무언가를 운반하는가?']
